# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/TreeVista/Test 1.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# customer_id          10000 non-null int64
# demographic_slice    10000 non-null object
# country_reg          10000 non-null object
# ad_exp               10000 non-null object
# est_income           10000 non-null float64
# hold_bal             10000 non-null float64
# pref_cust_prob       10000 non-null float64
# imp_cscore           10000 non-null int64
# RiskScore            10000 non-null float64
# imp_crediteval       10000 non-null float64
# axio_score           10000 non-null float64
# card_offer           10000 non-null bool
# dtypes: bool(1), float64(6), int64(2), object(3)
# memory usage: 869.2+ KB

# %%
df.columns
# Out:
# Index(['customer_id', 'demographic_slice', 'country_reg', 'ad_exp',
#        'est_income', 'hold_bal', 'pref_cust_prob', 'imp_cscore', 'RiskScore',
#        'imp_crediteval', 'axio_score', 'card_offer'],
#       dtype='object')

# %%
df.describe()
# Out:
#          customer_id     est_income      hold_bal  pref_cust_prob  \
# count   10000.000000   10000.000000  10000.000000    10000.000000
# mean   496819.831400   65853.355259     20.962621        0.329419
# std    287391.314157   31093.369592     18.841121        0.223299
# min       244.000000       2.054543     -2.140206        0.001781
# 25%    245172.500000   39165.786086      6.150577        0.156965
# 50%    495734.000000   76903.628763     11.913366        0.272263
# 75%    745475.250000   91032.514900     32.238914        0.459890
# max    999870.000000  150538.809704     81.759632        1.144357
#
#          imp_cscore     RiskScore  imp_crediteval    axio_score
# count  10000.000000  10000.000000    10000.000000  10000.000000
# mean     662.548800    670.042869       25.692162      0.393211
# std       90.549985     89.965854        1.889274      0.288243
# min      500.000000    324.436647       21.363123     -0.000052
# 25%      600.000000    609.231181       24.295435      0.139424
# 50%      655.000000    669.493442       25.611903      0.337841
# 75%      727.000000    730.484985       27.062519      0.624886
# max      849.000000   1004.497869       30.131214      1.000000

# %% [markdown]
# ### Cleaning the data

# %%
df.isna().any()
# Out:
# customer_id          False
# demographic_slice    False
# country_reg          False
# ad_exp               False
# est_income           False
# hold_bal             False
# pref_cust_prob       False
# imp_cscore           False
# RiskScore            False
# imp_crediteval       False
# axio_score           False
# card_offer           False
# dtype: bool

# %%
# Create a correlation matrix
corr_metrics = df.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col0 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col1 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col2 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col3 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col4 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col5 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col6 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col7 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow0_col8 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col0 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col1 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col2 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col3 {
#             background-color:  #fbf3f9;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col4 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col5 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col6 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col7 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow1_col8 {
#             background-color:  #c4cbe3;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col0 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col1 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col2 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col3 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col4 {
#             background-color:  #c6cce3;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col5 {
#             background-color:  #fbf4f9;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col6 {
#             background-color:  #cacee5;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col7 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow2_col8 {
#             background-color:  #f4eef6;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col0 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col1 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col2 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col3 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col4 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col5 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col6 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col7 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow3_col8 {
#             background-color:  #328dbf;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col0 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col1 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col2 {
#             background-color:  #cacee5;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col3 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col4 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col5 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col6 {
#             background-color:  #034b76;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col7 {
#             background-color:  #fbf4f9;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow4_col8 {
#             background-color:  #faf2f8;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col0 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col1 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col2 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col3 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col4 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col5 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col6 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col7 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow5_col8 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col0 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col1 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col2 {
#             background-color:  #ced0e6;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col3 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col4 {
#             background-color:  #034b76;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col5 {
#             background-color:  #fef6fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col6 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col7 {
#             background-color:  #fbf4f9;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow6_col8 {
#             background-color:  #faf3f9;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col0 {
#             background-color:  #fef6fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col1 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col2 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col3 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col4 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col5 {
#             background-color:  #fdf5fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col6 {
#             background-color:  #fcf4fa;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col7 {
#             background-color:  #023858;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow7_col8 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow8_col0 {
#             background-color:  #fff7fb;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow8_col1 {
#             background-color:  #c6cce3;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow8_col2 {
#             background-color:  #f7f0f7;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow8_col3 {
#             background-color:  #308cbe;
#         }    #T_f7b92886_04e0_11e9_b42f_81899258461crow8_col4 {
#             bac

# %%
# it seems feature 'imp_cscore' is correlated to 'imp_crediteval' , it's good to drop one of them for the sake of curse of DIm..

df_updated= df.drop(columns=['imp_crediteval'])

# %%
df_updated.describe()
# Out:
#          customer_id     est_income      hold_bal  pref_cust_prob  \
# count   10000.000000   10000.000000  10000.000000    10000.000000
# mean   496819.831400   65853.355259     20.962621        0.329419
# std    287391.314157   31093.369592     18.841121        0.223299
# min       244.000000       2.054543     -2.140206        0.001781
# 25%    245172.500000   39165.786086      6.150577        0.156965
# 50%    495734.000000   76903.628763     11.913366        0.272263
# 75%    745475.250000   91032.514900     32.238914        0.459890
# max    999870.000000  150538.809704     81.759632        1.144357
#
#          imp_cscore     RiskScore    axio_score
# count  10000.000000  10000.000000  10000.000000
# mean     662.548800    670.042869      0.393211
# std       90.549985     89.965854      0.288243
# min      500.000000    324.436647     -0.000052
# 25%      600.000000    609.231181      0.139424
# 50%      655.000000    669.493442      0.337841
# 75%      727.000000    730.484985      0.624886
# max      849.000000   1004.497869      1.000000

# %%
cat_df = df_updated.select_dtypes(include=['object']).copy()

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
# demographic_slice    10000 non-null object
# country_reg          10000 non-null object
# ad_exp               10000 non-null object
# dtypes: object(3)
# memory usage: 234.5+ KB

# %%
cat_df.head()
# Out:
#   demographic_slice country_reg ad_exp
# 0           AX03efs           W      N
# 1           AX03efs           E      N
# 2           AX03efs           W      Y
# 3           AX03efs           E      Y
# 4           AX03efs           W      N

# %%
df_updated['demographic_slice']= df_updated['demographic_slice'].astype('category')

# %%
#Label Encoding
df_updated['demographic_slice']= df_updated['demographic_slice'].cat.codes

# %%
#similary for rest of the other

# %%
df_updated['country_reg']= df_updated['country_reg'].astype('category')
df_updated['ad_exp']= df_updated['ad_exp'].astype('category')
df_updated['card_offer']= df_updated['card_offer'].astype('category')

# %%
#Label Encoding
df_updated['country_reg']= df_updated['country_reg'].cat.codes
df_updated['ad_exp']= df_updated['ad_exp'].cat.codes
df_updated['card_offer']= df_updated['card_offer'].cat.codes

# %%
df_updated.head(10)
# Out:
#    customer_id  demographic_slice  country_reg  ad_exp    est_income  \
# 0       713782                  0            1       0  33407.901749
# 1       515901                  0            0       0  19927.533533
# 2        95166                  0            1       1  51222.470997
# 3       425557                  0            0       1  67211.587467
# 4       624581                  0            1       0  20093.342158
# 5       721691                  0            0       0  73896.096129
# 6       269858                  0            1       0  73609.404135
# 7       219196                  0            1       0  57619.668582
# 8       413020                  0            1       1  49282.620299
# 9       174424                  0            1       0  57173.061392
#
#     hold_bal  pref_cust_prob  imp_cscore   RiskScore  axio_score  card_offer
# 0   3.000000        0.531112         619  503.249027    0.137289           0
# 1  20.257927        0.297439         527  820.108146    0.052264           0
# 2   4.000000        0.018463         606  586.605795    0.452035           0
# 3  18.653631        0.089344         585  634.701982    0.564619           0
# 4   4.000000        0.094948         567  631.949979    0.917304           0
# 5  12.906641        0.656848         560  809.333963    0.198511           1
# 6   3.000000        0.137818         620  697.308163    0.179141           0
# 7   9.000000        0.367879         658  668.075472    0.035338           0
# 8   0.000000        0.182079         519  656.111591    0.054130           0
# 9   6.000000        0.288242         645  547.767117    0.648325           0

# %%
df_updated.columns
# Out:
# Index(['customer_id', 'demographic_slice', 'country_reg', 'ad_exp',
#        'est_income', 'hold_bal', 'pref_cust_prob', 'imp_cscore', 'RiskScore',
#        'axio_score', 'card_offer'],
#       dtype='object')

# %%
offer= df_updated['card_offer']
users= df_updated['customer_id']

df_final= df_updated.drop(columns=['card_offer','customer_id'])

# %%
#splitting the data in training and test DataSets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train,  y_test = train_test_split(df_final, offer, test_size=0.2, random_state=0)

# %%
#feature scaling

from sklearn.preprocessing  import StandardScaler
sc_X = StandardScaler()
X_train2 = pd.DataFrame(sc_X.fit_transform(X_train))
X_test2 = pd.DataFrame(sc_X.fit_transform(X_test))   

X_train2.columns= X_train.columns.values
X_test2.columns= X_test.columns.values
X_train2.index= X_train.index.values
X_test2.index= X_test.index.values

X_train= X_train2
X_test= X_test2

#X_test= np.squeeze(sc_X.transform(X_test.values.reshape(-1, 1)))

# %%
#ready for modelling

#Logistic Reg

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#predicting Test Set

y_pred_LR= classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score , recall_score
acc= accuracy_score (y_test, y_pred_LR)
prec= precision_score(y_test,y_pred_LR)
rec= recall_score (y_test, y_pred_LR)
f1= f1_score(y_test,y_pred_LR)

# %%
pd.DataFrame([['Log Regr', acc, prec, rec, f1]], columns= ['Model','Accuracy','Precision','Recall','F1'])
# Out:
#       Model  Accuracy  Precision    Recall        F1
# 0  Log Regr    0.9665   0.905724  0.873377  0.889256

# %%
#lets check with different model

# %%
from sklearn.svm import SVC
classifier = SVC(random_state=0, kernel='linear')
classifier.fit(X_train, y_train)

#predicting Test Set

y_pred_SVC= classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score , recall_score
acc= accuracy_score (y_test, y_pred_SVC)
prec= precision_score(y_test,y_pred_SVC)
rec= recall_score (y_test, y_pred_SVC)
f1= f1_score(y_test,y_pred_SVC)

pd.DataFrame([['SVM', acc, prec, rec, f1]], columns= ['Model','Accuracy','Precision','Recall','F1'])
# Out:
#   Model  Accuracy  Precision    Recall        F1
# 0   SVM     0.966   0.902685  0.873377  0.887789

# %% [markdown]
# ### Conculsuiion from above results:
#  #### 1. RBF kernel worked better than linear kernel but not good than that of Log Regr

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(random_state=0, n_estimators=100, criterion = 'entropy')
classifier.fit(X_train, y_train)

#predicting Test Set

y_pred_RC= classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score , recall_score
acc= accuracy_score (y_test, y_pred_RC)
prec= precision_score(y_test,y_pred_RC)
rec= recall_score (y_test, y_pred_RC)
f1= f1_score(y_test,y_pred_RC)

pd.DataFrame([['Random Forest with 100 trees', acc, prec, rec, f1]], columns= ['Model','Accuracy','Precision','Recall','F1'])
#print(svm_results)
# Out:
#                           Model  Accuracy  Precision    Recall        F1
# 0  Random Forest with 100 trees    0.9755    0.94198  0.896104  0.918469

# %% [markdown]
# ## Final Conclusion

# %% [markdown]
# ### RFC performed best among the rest of the classifiers with an accuracy of 97.55 percent and F1 score 0.918 on the training
#
# #### first dataset named "Test1.csv" , please note , no  dataset  ds1 & ds4 was provided in mail communication"
# #### I will proceed with the RFC model for the test2.csv data
